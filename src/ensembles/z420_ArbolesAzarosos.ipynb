# %% [markdown]
# # 4. Ensembles de Arboles de Decision

# %% [markdown]
# Un arbol de decisión es un modelo débil, el aumento del poder predictivo proviene al ensamblar varios arboles de decisión.
# <br> Si promedio n arboles identicos, el resultados es exactamente el mismo que utilizar un solo arbol, necesito PERTURBAR cada arbol para disponer de variablidad

# %% [markdown]
# la variabilidad provendrá de estas fuentes:
#
#
# *   Perturbar el dataset
# *   Perturbar el algoritmo del arbol
# *   Perturbar el dataset y el algoritmo del arbol al mismo tiempo

# %% [markdown]
# Se verán estos tres algoritmos
#
#
# *   Arboles Azarosos
# *   Random Forest
# *   Gradient Boosting of Decision Trees

# %% [markdown]
# #### 4.01 Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
# %%shell
# pip install --upgrade kaggle

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -sfn "/content/.drive/My Drive/dmeyf"   /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


# defino funcion descargar()
descargar() {
  carpeta_destino="/content/buckets/b1/datasets/"
  url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
  archivo="$1"

  if ! test -f "$carpeta_destino""$archivo"; then
    wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
  fi

  if ! test -f  "/content/datasets/""$archivo"; then
    cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
  fi;
}

# hago la descarga efectiva, llamando a descargar()
descargar  "dataset_pequeno.csv"

#************************************
# %%shell

# # Ruta real dentro de tu Google Drive (estructura no estándar)
# RUTA_DMEYF="/content/.drive/My Drive/Capacitacion/Maestria Data Minning/09-Aplicaciones_mineria_datos_en_economia/dmeyf"

# mkdir -p "$RUTA_DMEYF"
# mkdir -p "/content/buckets"
# ln -sfn "$RUTA_DMEYF"   /content/buckets/b1

# mkdir -p ~/.kaggle
# cp "/content/drive/MyDrive/Capacitacion/Maestria Data Minning/09-Aplicaciones_mineria_datos_en_economia/dmeyf/kaggle/kaggle.json"  ~/.kaggle
# chmod 600 ~/.kaggle/kaggle.json


# mkdir -p "/content/buckets/b1/exp"
# mkdir -p "/content/buckets/b1/datasets"
# mkdir -p "/content/datasets"


# # defino funcion descargar()
# descargar() {
#   carpeta_destino="/content/buckets/b1/datasets/"
#   url_origen="https://storage.googleapis.com/open-courses/utn2026-b40a/"
#   archivo="$1"

#   if ! test -f "$carpeta_destino""$archivo"; then
#     wget  "$url_origen""$archivo"  -O "$carpeta_destino""$archivo"
#   fi

#   if ! test -f  "/content/datasets/""$archivo"; then
#     cp  "$carpeta_destino""$archivo"  "/content/datasets/""$archivo"
#   fi;
# }

# # hago la descarga efectiva, llamando a descargar()
# descargar  "dataset_pequeno.csv"

# %%
# %%shell
# ls -la ~/.kaggle/kaggle.json
# cat ~/.kaggle/kaggle.json

# %%
# %%shell
# kaggle competitions submissions -c utn-2026-inicial

# %% [markdown]
# ---

# %% [markdown]
# ## 4.02 Arboles Azarosos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Arboles Azarosos es el nombre de un algoritmo trivial (por favor NO confundir con Random Forest)
# Qué tipo de perturbaciones se realizan en Arboles Azarosos
# * Se perturba el dataset
# * No se perturba el algoritmo, es siempre rpart original

# %% [markdown]
# Cada  arbolito de  Arboles Azarosos se entrena sobre un dataset perturbado,  que tiene exactamente la misma cantidad de registros pero solo un subconjunto de los atributos (campos)  del dataset, tomados al azar, de los originales.
# <br> En esta primera corrida, se construira cada arbol en un dataset utilizando el 50% de los campos

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Aug 20 07:01:35 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  671287 35.9 1473300    78.7 1473300  78.7
# Vcells 1242646  9.5 8388608    64.0 1978711  15.1

# %%
# cargo las librerias que necesito
require("data.table")
require("rpart")
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%
#
#
# Loading required package: rpart

# %% [markdown]
# Aqui debe cargar SU semilla primigenia

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 389437

# parametros  arbol
# entreno cada arbol con solo 50% de las variables variables
#  por ahora, es fijo
PARAM$feature_fraction <- 0.5

PARAM$rpart$cp <- -3
PARAM$rpart$minsplit <- 8
PARAM$rpart$minbucket <- 200
PARAM$rpart$maxdepth <- 30

# voy a generar 512 arboles,
#  a mas arboles mas tiempo de proceso y MEJOR MODELO,
#  pero ganancias marginales
PARAM$num_trees_max <- 512

# %%
####   CANI# ============================================================
# Reconstruyo el entorno: el runtime R es una VM nueva,
# no hereda nada de lo hecho en Python3 (ni el symlink ni kaggle.json)
# ============================================================

# 1) Verificar si Drive ya está montado en esta sesión R
if (!dir.exists("/content/drive/MyDrive")) {
  stop(paste0(
    "Drive no está montado en este runtime R.\n",
    "Andá al icono de carpeta del panel izquierdo (Files) y ",
    "hacé click en 'Mount Drive', autorizá, y volvé a correr esta celda."
  ))
}

# 2) Recrear el symlink /content/buckets/b1 -> Drive/dmeyf
system('mkdir -p /content/buckets')
system('ln -sfn "/content/drive/MyDrive/dmeyf" /content/buckets/b1')

# 3) Volver a copiar kaggle.json (se pierde con cada VM nueva)
system('mkdir -p ~/.kaggle')
system('cp /content/buckets/b1/kaggle/kaggle.json ~/.kaggle')
system('chmod 600 ~/.kaggle/kaggle.json')

# 4) Asegurar que exista la carpeta de experimentos
system('mkdir -p /content/buckets/b1/exp')

# 5) Chequeo rápido de que todo quedó en su lugar
cat("Symlink OK:", dir.exists("/content/buckets/b1"), "\n")
cat("kaggle.json OK:", file.exists("~/.kaggle/kaggle.json") || file.exists(path.expand("~/.kaggle/kaggle.json")), "\n")
cat("Carpeta exp OK:", dir.exists("/content/buckets/b1/exp"), "\n")
# Out:
# Symlink OK: TRUE
# kaggle.json OK: TRUE
# Carpeta exp OK: TRUE

# %%
# carpeta de trabajo
setwd("/content/buckets/b1/exp")
experimento <- "exp4020"
dir.create(experimento, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %%
experimento <- "exp4020"
# Construir el camino completo a la carpeta del experimento
full_experimento_path <- paste0("/content/buckets/b1/exp/", experimento)
# Asegurar que la carpeta del experimento exista, creándola recursivamente si es necesario
dir.create(full_experimento_path, showWarnings=FALSE, recursive = TRUE)
# Establecer el directorio de trabajo a la carpeta del experimento
setwd(full_experimento_path)

# %%
# lectura del dataset
dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
# defino los dataset de entrenamiento y aplicacion
dtrain <- dataset[foto_mes == 202107]
dfuture <- dataset[foto_mes == 202109]

# arreglo clase_ternaria por algun distraido ""
dfuture[, clase_ternaria := NA ]

# %%
# Establezco cuales son los campos que puedo usar para la prediccion
# el copy() es por la Lazy Evaluation
campos_buenos <- copy(setdiff(colnames(dtrain), c("clase_ternaria")))

# %%
# que tamanos de ensemble grabo a disco
grabar <- c(1, 2, 4, 8, 16, 32, 64, 128, 256, 384, 512)

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
# aqui se va acumulando la probabilidad del ensemble
tb_prediccion[, prob_acumulada := 0]

# %%
set.seed(PARAM$semilla_primigenia) # Establezco la semilla aleatoria

# %%
for (arbolito in seq(PARAM$num_trees_max) ) {
  message( arbolito, " ")
  qty_campos_a_utilizar <- as.integer(length(campos_buenos)
    * PARAM$feature_fraction)

  # elijo los campos al azar
  campos_random <- sample(campos_buenos, qty_campos_a_utilizar)

  # paso de un vector a un string con los elementos
  # separados por un signo de "+"
  # este hace falta para la formula
  campos_random <- paste(campos_random, collapse= " + ")

  # armo la formula para rpart
  formulita <- paste0("clase_ternaria ~ ", campos_random)

  # genero el arbol de decision
  modelo <- rpart(formulita,
    data= dtrain,
    xval= 0,
    control= PARAM$rpart
  )

  # aplico el modelo a los datos que no tienen clase
  prediccion <- predict(modelo, dfuture, type= "prob")

  tb_prediccion[, prob_acumulada := prob_acumulada + prediccion[, "BAJA+2"]]

  if (arbolito %in% grabar) {
    umbral_corte <- (1 / 40) * arbolito
    tb_prediccion[, Predicted := as.numeric(prob_acumulada > umbral_corte)]

    archivo_kaggle <- paste0(
        "KA420_",
        sprintf("%.3d", arbolito), # para que tenga ceros adelante
        ".csv"
      )

    # grabo el archivo
    fwrite( tb_prediccion[, list(numero_de_cliente, Predicted)],
      file= archivo_kaggle,
      sep= ","
    )

    # subida a Kaggle
    comando <- "kaggle competitions submit"
    competencia <- "-c utn-2026-inicial"
    arch <- paste( "-f", archivo_kaggle)

    mensaje <- paste0("-m 'cp=", PARAM$rpart$cp, "  minsplit=", PARAM$rpart$minsplit, "  minbucket=", PARAM$rpart$minbucket, " maxdepth=", PARAM$rpart$maxdepth, "'" )
    linea <- paste( comando, competencia, arch, mensaje)
    salida <- system(linea, intern=TRUE)
    cat(salida)
  }
}
# Out:
# 1

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %%
str(PARAM$rpart)
# Out:
# List of 4
#  $ cp       : num -3
#  $ minsplit : num 8
#  $ minbucket: num 200
#  $ maxdepth : num 30

# %% [markdown]
# ---
